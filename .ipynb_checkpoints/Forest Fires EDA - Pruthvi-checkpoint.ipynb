# %% [markdown]
# # Project Title

# %% [markdown]
# ### Step 1 - Define the problem and goal

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
forest_fires = pd.read_csv("forest_fire_dataset.csv")

# %%
forest_fires.shape
# Out:
# (14186, 27)

# %%
forest_fires.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14186 entries, 0 to 14185
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  14186 non-null  int64
#  1   FIRE_ID                     14186 non-null  object
#  2   Fire Name                   14186 non-null  object
#  3   Acres                       14186 non-null  float64
#  4   Date                        14186 non-null  object
#  5   Fire Type                   14186 non-null  object
#  6   LATITUDE                    14186 non-null  float64
#  7   LONGITUDE                   14186 non-null  float64
#  8   time                        14186 non-null  object
#  9   weathercode                 14186 non-null  int64
#  10  temperature_2m_max          14186 non-null  float64
#  11  temperature_2m_min          14186 non-null  float64
#  12  temperature_2m_mean         14186 non-null  float64
# ...

# %% [markdown]
# The dataset consists of 14186 observations and 27 features.
#
# The various features are described below.
# - FIRE_ID - A unique identifier assigned to each fire
# - Fire Name - Unique name given to the fire
# - Acres - Total number of acres burned by the fire
# - Date - Date when the fire was first ignited
# - Fire Type - Represents the type of the fire. It can take values like "Wildfire", "Prescribed Fire", or "Human-caused"
# - LATITUDE - Latitude of the location. Ranges from -90 to 90
# - LONGITUDE - Longitude of the location. Ranges from -180 to 180
# - time - Date when the fire was first ignited
# - weathercode - The most severe weather condition on a given day (WMO code)
# - temperature_2m_max - Maximum daily air temperature at 2 meters above ground (°C)
# - temperature_2m_min - Minimum daily air temperature at 2 meters above ground (°C)
# - temperature_2m_mean - Mean daily air temperature at 2 meters above ground (°C)
# - apparent_temperature_max - Maximum and minimum daily apparent temperature. Apparent temperature, also known as feels like, is the temperature equivalent perceived by humans, caused by the combined effects of air temperature, relative humidity and wind speed (°C)
# - apparent_temperature_min - Minimum daily apparent temperature (°C)
# - apparent_temperature_mean - Mean daily apparent temperature (°C)
# - sunrise - Sun rise time (iso8601)
# - sunset - Sun set time (iso8601)
# - shortwave_radiation_sum - The sum of solar radiation on a given day in Megajoules (MJ/m²)
# - precipitation_sum - Sum of daily precipitation, including rain, showers and snowfall (mm)
# - rain_sum - Sum of daily rain (mm)
# - snowfall_sum - Sum of daily snowfall (mm)
# - precipitation_hours - The number of hours with rain (hours)
# - windspeed_10m_max - Maximum wind speed on a day (km/h)
# - windgusts_10m_max - Maximum wind gusts on a day (km/h)
# - winddirection_10m_dominant - Dominant wind direction (°)
# - et0_fao_evapotranspiration - Daily sum of ET₀ Reference Evapotranspiration of a well watered grass field (mm)

# %% [markdown]
# ### Step 2 - Data Wrangling

# %% [markdown]
# ##### 2A - Data Gathering

# %% [markdown]
# ##### 2B - Describe the dataset

# %% [markdown]
# ##### 2C - Data Assesment

# %% [markdown]
# ###### Manual Assesment
# Observations after skimming through the dataset:
# - Not all fires are assigned a name (Indicated by the value UNNAMED in the Fire Name column)
# - Strangely there are integer values in the Fire Name column (For instance, observation numbered 231)
# - Fire Type has the value "Wildfire" throughout the dataset for all observations
# - The features date and time have the same value i.e, the date of fire ignition contrary to what one might presume
# - sunrise and sunset contains both date and time
# - precipitation_sum equals rain_sum throughout the dataset
# - snowfall_sum equals 0 throughout the dataset
# - No missing values found in the dataset

# %% [markdown]
# ###### Programmatic Assesment

# %%
forest_fires.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14186 entries, 0 to 14185
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  14186 non-null  int64
#  1   FIRE_ID                     14186 non-null  object
#  2   Fire Name                   14186 non-null  object
#  3   Acres                       14186 non-null  float64
#  4   Date                        14186 non-null  object
#  5   Fire Type                   14186 non-null  object
#  6   LATITUDE                    14186 non-null  float64
#  7   LONGITUDE                   14186 non-null  float64
#  8   time                        14186 non-null  object
#  9   weathercode                 14186 non-null  int64
#  10  temperature_2m_max          14186 non-null  float64
#  11  temperature_2m_min          14186 non-null  float64
#  12  temperature_2m_mean         14186 non-null  float64
# ...

# %% [markdown]
# Observations
# - Date should be of type datetime
# - Need to find a way to represent the location attributes (latitude and longitude)
# - sunrise and sunset should be of type datetime
# - There are no missing values in the dataset.
# -

# %% [markdown]
# Questions we would like to explore.
# - Is the FIRE_ID unique across all the observations?
# - Is the Fire Name unique across the observations?

# %% [markdown]
# ##### 2D - Data Cleaning

# %% [markdown]
# ### Step 4 - EDA

# %% [markdown]
# ##### 4A - Univariate Analysis

# %% [markdown]
# ## Variable - temperature_2m_mean
# Conclusions
# - It is almost normally distributed
# - There are outliers
# - No missing values

# %%
forest_fires['temperature_2m_mean'].describe()
# Out:
# count    14186.000000
# mean        20.660130
# std          6.858652
# min        -32.400000
# 25%         16.400000
# 50%         21.400000
# 75%         25.800000
# max         40.800000
# Name: temperature_2m_mean, dtype: float64

# %%
forest_fires['temperature_2m_mean'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
forest_fires['temperature_2m_mean'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
forest_fires['temperature_2m_mean'].skew()
# Out:
# -0.6214194300432309

# %%
forest_fires['temperature_2m_mean'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# ## Variable - apparent_temperature_mean
# Conclusions
# - It is almost normally distributed
# - There are outliers
# - No missing values
# - The distribution looks similar to temperature_2m_mean

# %%
forest_fires['apparent_temperature_mean'].describe()
# Out:
# count    14186.000000
# mean        18.424270
# std          7.979973
# min        -37.300000
# 25%         13.600000
# 50%         19.400000
# 75%         23.900000
# max         39.300000
# Name: apparent_temperature_mean, dtype: float64

# %%
forest_fires['apparent_temperature_mean'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
forest_fires['apparent_temperature_mean'].plot(kind='box')
# Out:
# <Axes: >

# %%
forest_fires['apparent_temperature_mean'].skew()
# Out:
# -0.5497731214934708

# %% [markdown]
# ## Variable - shortwave_radiation_sum
# Conclusions
# - It is almost normally distributed
# - There are outliers
# - No missing values

# %%
forest_fires['shortwave_radiation_sum'].describe()
# Out:
# count    14186.000000
# mean        23.868809
# std          5.573375
# min          0.240000
# 25%         21.000000
# 50%         24.830000
# 75%         27.940000
# max         33.670000
# Name: shortwave_radiation_sum, dtype: float64

# %%
forest_fires['shortwave_radiation_sum'].skew()
# Out:
# -0.8907280403799643

# %%
forest_fires['shortwave_radiation_sum'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
forest_fires['shortwave_radiation_sum'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# ## Variable - precipitation_sum
# Conclusions
# - It is highly positively skewed
# - There are outliers
# - No missing values

# %%
forest_fires['precipitation_sum'].describe()
# Out:
# count    14186.000000
# mean         0.523953
# std          1.745412
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.200000
# max         54.500000
# Name: precipitation_sum, dtype: float64

# %%
forest_fires['precipitation_sum'].skew()
# Out:
# 8.41211901690372

# %%
forest_fires['precipitation_sum'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
forest_fires['precipitation_sum'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# `After log transforming precipitation_sum

# %%
sns.kdeplot(np.log(forest_fires[forest_fires['precipitation_sum']>0]['precipitation_sum']))
# Out:
# <Axes: xlabel='precipitation_sum', ylabel='Density'>

# %%
pd.Series(np.log(forest_fires[forest_fires['precipitation_sum']>0]['precipitation_sum'])).skew()
# Out:
# 0.17522678109957346

# %% [markdown]
# ## Variable - windspeed_10m_max
# Conclusions
# - It is highly positively skewed
# - There are outliers
# - No missing values

# %%
forest_fires['windspeed_10m_max'].describe()
# Out:
# count    14186.000000
# mean        18.179268
# std          8.369749
# min          2.800000
# 25%         12.200000
# 50%         16.200000
# 75%         22.300000
# max         58.500000
# Name: windspeed_10m_max, dtype: float64

# %%
forest_fires['windspeed_10m_max'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
forest_fires['windspeed_10m_max'].skew()
# Out:
# 1.3013144454568237

# %% [markdown]
# After log transforming windspeed_10m_max

# %%
pd.Series(np.log(forest_fires[forest_fires['windspeed_10m_max']>0]['windspeed_10m_max'])).skew()
# Out:
# 0.13066741134113521

# %%
sns.kdeplot(np.log(forest_fires[forest_fires['windspeed_10m_max']!=0]['windspeed_10m_max']))
# Out:
# <Axes: xlabel='windspeed_10m_max', ylabel='Density'>

# %%
forest_fires['windspeed_10m_max'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# ## Variable - precipitation_hours
# Conclusions
# - It is highly positively skewed
# - There are outliers
# - No missing values

# %%
forest_fires["precipitation_hours"].describe()
# Out:
# count    14186.000000
# mean         0.896095
# std          1.989058
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max         23.000000
# Name: precipitation_hours, dtype: float64

# %%
forest_fires["precipitation_hours"].skew()
# Out:
# 3.832689722758098

# %%
forest_fires["precipitation_hours"].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
forest_fires["precipitation_hours"].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# After log transforming precipitation_hours

# %%
pd.Series(np.log(forest_fires[forest_fires['precipitation_hours']>0]['precipitation_hours'])).skew()
# Out:
# 0.6026348702709428

# %%
sns.kdeplot(np.log(forest_fires[forest_fires['precipitation_hours']!=0]['precipitation_hours']))
# Out:
# <Axes: xlabel='precipitation_hours', ylabel='Density'>

# %%
## Variable - windgusts_10m_max         
Conclusions
- It is highly positively skewed
- There are outliers
- No missing values

# %%
forest_fires["windgusts_10m_max"].describe()
# Out:
# count    14186.000000
# mean        41.943071
# std         13.983075
# min         11.900000
# 25%         32.000000
# 50%         39.600000
# 75%         49.300000
# max        132.100000
# Name: windgusts_10m_max, dtype: float64

# %%
forest_fires["windgusts_10m_max"].skew()
# Out:
# 0.9772872677839572

# %%
forest_fires["windgusts_10m_max"].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
forest_fires["windgusts_10m_max"].plot(kind='box')
# Out:
# <Axes: >

# %%
## Variable - winddirection_10m_dominant         
Conclusions
- It is highly positively skewed
- There are outliers
- No missing values

# %%
forest_fires["winddirection_10m_dominant"].describe()
# Out:
# count    14186.000000
# mean       204.221979
# std         86.290997
# min          0.000000
# 25%        155.000000
# 50%        216.000000
# 75%        267.000000
# max        360.000000
# Name: winddirection_10m_dominant, dtype: float64

# %%
forest_fires["winddirection_10m_dominant"].skew()
# Out:
# -0.49333748776645575

# %%
forest_fires["winddirection_10m_dominant"].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
forest_fires["winddirection_10m_dominant"].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# ## Variable - et0_fao_evapotranspiration
# Conclusions
# - It is almost normally distributed
# - There are outliers
# - There are missing values

# %%
forest_fires["et0_fao_evapotranspiration"].describe()
# Out:
# count    14186.000000
# mean         5.736591
# std          1.935270
# min          0.000000
# 25%          4.410000
# 50%          5.735000
# 75%          7.040000
# max         14.840000
# Name: et0_fao_evapotranspiration, dtype: float64

# %%
forest_fires["et0_fao_evapotranspiration"].skew()
# Out:
# 0.15875565000344846

# %%
forest_fires["et0_fao_evapotranspiration"].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
forest_fires["et0_fao_evapotranspiration"].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# ## Variable - Acres
# Conclusions
# - It is almost normally distributed
# - There are outliers
# - No missing values

# %%
forest_fires["Acres"].describe()
# Out:
# count     14186.000000
# mean      10426.834555
# std       30879.531354
# min         500.000000
# 25%        1464.000000
# 50%        2754.500000
# 75%        7034.250000
# max      657299.000000
# Name: Acres, dtype: float64

# %%
forest_fires["Acres"].skew()
# Out:
# 9.240413471251717

# %%
forest_fires["Acres"].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
forest_fires["Acres"].plot(kind='box')
# Out:
# <Axes: >

# %%
pd.Series(np.log(forest_fires[forest_fires['Acres']>0]['Acres'])).skew()
# Out:
# 1.0063583669753262

# %%
sns.kdeplot(np.log(forest_fires[forest_fires['Acres']!=0]['Acres']))
# Out:
# <Axes: xlabel='Acres', ylabel='Density'>

# %% [markdown]
# ##### 4B - Bivariate Analysis

# %%
forest_fires["log_windspeed_10m_max"] = np.log(forest_fires["windspeed_10m_max"])
forest_fires["log_acres"] = np.log(forest_fires["Acres"])
sns.scatterplot(data=forest_fires, x='log_windspeed_10m_max', y='log_acres')
# Out:
# <Axes: xlabel='log_windspeed_10m_max', ylabel='log_acres'>

# %%
forest_fires["log_acres"] = np.log(forest_fires["Acres"])
sns.scatterplot(data=forest_fires, x='temperature_2m_mean', y='log_acres')
# Out:
# <Axes: xlabel='temperature_2m_mean', ylabel='log_acres'>

# %%
forest_fires["precipitation_sum"] = np.log(forest_fires["precipitation_sum"])
forest_fires["log_acres"] = np.log(forest_fires["Acres"])
sns.scatterplot(data=forest_fires, x='precipitation_sum', y='log_acres')
# Out:
# C:\Users\ADMIN\PycharmProjects\IDMP\venv\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <Axes: xlabel='precipitation_sum', ylabel='log_acres'>

# %%
sns.scatterplot(data=forest_fires, x='precipitation_hours', y='log_acres')
# Out:
# <Axes: xlabel='precipitation_hours', ylabel='log_acres'>

# %%
sns.scatterplot(data=forest_fires, x='et0_fao_evapotranspiration', y='log_acres')
# Out:
# <Axes: xlabel='et0_fao_evapotranspiration', ylabel='log_acres'>

# %%
sns.scatterplot(data=forest_fires, x='winddirection_10m_dominant', y='log_acres')
# Out:
# <Axes: xlabel='winddirection_10m_dominant', ylabel='log_acres'>

# %% [markdown]
# ##### 4C - Multivariate Analysis

# %% [markdown]
# ##### 4D - Feature Engineering

# %% [markdown]
# ##### 4E - Removing Outliers

# %% [markdown]
# ##### 4F - Imputing missing values

# %% [markdown]
# ##### 4G - Repeat EDA until done

# %% [markdown]
# ### Step 5 - Documenting conclusions

# %% [markdown]
# ### Step 6 - Modeling

# %% [markdown]
# ### Step 7 - Hyperparameter tuning

# %% [markdown]
# ### Step 8 - Visualizing results

# %% [markdown]
# ### Step 9 - Deployment
