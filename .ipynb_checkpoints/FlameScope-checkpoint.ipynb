# %% [markdown]
# # Forest Fires UCI

# %% [markdown]
# ### Step 1 - Define the problem and goal

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
forest_fires = pd.read_csv("forest_fire_dataset.csv")

# %%
forest_fires.shape
# Out:
# (14186, 27)

# %%
forest_fires.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       517 non-null    int64
#  1   Y       517 non-null    int64
#  2   month   517 non-null    object
#  3   day     517 non-null    object
#  4   FFMC    517 non-null    float64
#  5   DMC     517 non-null    float64
#  6   DC      517 non-null    float64
#  7   ISI     517 non-null    float64
#  8   temp    517 non-null    float64
#  9   RH      517 non-null    int64
#  10  wind    517 non-null    float64
#  11  rain    517 non-null    float64
#  12  area    517 non-null    float64
# dtypes: float64(8), int64(3), object(2)
# memory usage: 52.6+ KB

# %%
forest_fires.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %% [markdown]
# The dataset consists of 517 observations and 13 features.
#
# The various features are described below.
# 1. X - x-axis spatial coordinate within the Montesinho park map: 1 to 9
# 2. Y - y-axis spatial coordinate within the Montesinho park map: 2 to 9
# 3. month - month of the year: 'jan' to 'dec'
# 4. day - day of the week: 'mon' to 'sun'
# 5. FFMC - FFMC index from the FWI system: 18.7 to 96.20
# 6. DMC - DMC index from the FWI system: 1.1 to 291.3
# 7. DC - DC index from the FWI system: 7.9 to 860.6
# 8. ISI - ISI index from the FWI system: 0.0 to 56.10
# 9. temp - temperature in Celsius degrees: 2.2 to 33.30
# 10. RH - relative humidity in %: 15.0 to 100
# 11. wind - wind speed in km/h: 0.40 to 9.40
# 12. rain - outside rain in mm/m2 : 0.0 to 6.4
# 13. area - the burned area of the forest (in ha): 0.00 to 1090.84

# %% [markdown]
# ### Step 2 - Data Wrangling

# %% [markdown]
# ##### 2A - Data Gathering

# %% [markdown]
# ##### 2B - Describe the dataset

# %% [markdown]
# ##### 2C - Data Assesment

# %% [markdown]
# ###### Manual Assesment
# Observations after skimming through the dataset:
# - Area is 0 for almost half of the values. As its the target variable, we have to either drop or impute carefully.
# - Most of the values for the variable rain is 0.
# - No missing values found in the dataset

# %% [markdown]
# ###### Programmatic Assesment
#
# 1. Data looks clean and the variables have specicific types representing and adhers to the definition.

# %% [markdown]
# ##### 2D - Data Cleaning

# %% [markdown]
# There are no null data but values for area is 0 in some observations. This needs to be handled in some way.
#
# As its our target variable, and is important
#
# 1. We can drop those rows
#
# Else,
#
# As our dataset is very small
#
# 2. We cam impute values as its all based on specific region, assuming these are missing values
#
# For our understanding of the data better, lets go ahead with both options

# %%
df_dropped_area = forest_fires.drop(forest_fires[forest_fires['area'] == 0].index)
df_dropped_area.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 270 entries, 138 to 514
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       270 non-null    int64
#  1   Y       270 non-null    int64
#  2   month   270 non-null    object
#  3   day     270 non-null    object
#  4   FFMC    270 non-null    float64
#  5   DMC     270 non-null    float64
#  6   DC      270 non-null    float64
#  7   ISI     270 non-null    float64
#  8   temp    270 non-null    float64
#  9   RH      270 non-null    int64
#  10  wind    270 non-null    float64
#  11  rain    270 non-null    float64
#  12  area    270 non-null    float64
# dtypes: float64(8), int64(3), object(2)
# memory usage: 29.5+ KB

# %% [markdown]
# We will go ahead with Multiple Imputation - https://scikit-learn.org/stable/modules/impute.html
#
# This method is computationaly intensive, but our dataset is small hence it is feasible. Also it tries different imputation methods and provides us with the one that is more statistically accurate.
#
# Multiple imputation accounts for the uncertainty associated with imputed values and can provide more accurate estimates of parameters and uncertainties in the analysis

# %%
dataset_imputed_area = forest_fires.copy()

from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# Replace 0 values with NaN
dataset_imputed_area['area'] = dataset_imputed_area['area'].replace(0, float('nan'))

# Perform multiple imputation using IterativeImputer
imputer = IterativeImputer(n_nearest_features=5, initial_strategy='median', random_state=0)
dataset_imputed_area['area'] = imputer.fit_transform(dataset_imputed_area[['area']])

# %% [markdown]
# ### Step 4 - EDA

# %% [markdown]
# ##### 4A - Univariate Analysis

# %% [markdown]
# 1. Lets see variable FFMC

# %%
def univariate_analysys(target_name, target):
    # Histogram
    plt.figure(figsize=(8, 6))
    sns.histplot(target, bins=10)
    plt.title(target_name)
    plt.xlabel("Value")
    plt.ylabel("Frequency")
    plt.show()

    # Box plot
    plt.figure(figsize=(8, 6))
    sns.boxplot(y=target)
    plt.title(target_name)
    plt.ylabel("Value")
    plt.show()

    # Measures of central tendency
    print("Mean:", target.mean())
    print("Median:", target.median())
    print("Mode:", target.mode().iloc[0])

    # Measures of dispersion
    print("Range:", target.max() - target.min())
    print("Variance:", target.var())
    print("Standard Deviation:", target.std())

    # Measure of skewness
    print("Measure of Skewness:", target.skew())

# %%
univariate_analysys('FFMC', dataset_imputed_area['FFMC'])
# Out:
# Mean: 90.64468085106384
# Median: 91.6
# Mode: 91.6
# Range: 77.5
# Variance: 30.471623783605448
# Standard Deviation: 5.5201108488512665
# Measure of Skewness: -6.575605977178827

# %% [markdown]
# Data is left skewed. Hence we can apply exponential transformation

# %%
from scipy.stats import boxcox
lambda_value = 16
new_target = boxcox(dataset_imputed_area['FFMC'], lmbda=lambda_value)
univariate_analysys('Exponential FFMC', new_target)
# Out:
# Mean: 1.5594662141168773e+30
# Median: 1.5353507166136475e+30
# Mode: 1.5353507166136475e+30
# Range: 3.3626461567718694e+30
# Variance: 4.616610647538248e+59
# Standard Deviation: 6.794564480184325e+29
# Measure of Skewness: 0.1250071532906825

# %% [markdown]
# 2. DMC

# %%
univariate_analysys('DMC', dataset_imputed_area['DMC'])
# Out:
# Mean: 110.87234042553192
# Median: 108.3
# Mode: 99.0
# Range: 290.2
# Variance: 4101.951888504046
# Standard Deviation: 64.0464822492543
# Measure of Skewness: 0.5474977944865835

# %% [markdown]
# This looks normal

# %%
univariate_analysys('DC', dataset_imputed_area['DC'])
# Out:
# Mean: 547.9400386847195
# Median: 664.2
# Mode: 745.3
# Range: 852.7
# Variance: 61536.83546744042
# Standard Deviation: 248.06619170584375
# Measure of Skewness: -1.1004451245649132

# %% [markdown]
# It is left skew, lets try exponential transformation

# %%
from scipy.stats import boxcox
lambda_value = 4
new_target = boxcox(dataset_imputed_area['DC'], lmbda=lambda_value)
univariate_analysys('Exponential DC', new_target)
# Out:
# Mean: 43633626353.056335
# Median: 48655898151.622475
# Mode: 77137310691.99194
# Range: 137134072196.04053
# Variance: 1.0767679351247629e+21
# Standard Deviation: 32814142303.65869
# Measure of Skewness: 0.280692228930135

# %% [markdown]
# ISI

# %%
univariate_analysys("ISI", dataset_imputed_area["ISI"])
# Out:
# Mean: 9.021663442940039
# Median: 8.4
# Mode: 9.6
# Range: 56.1
# Variance: 20.78883211131602
# Standard Deviation: 4.5594771752160375
# Measure of Skewness: 2.5363252664156875

# %% [markdown]
# This is right skew, lets apply log transformation and check

# %%
non_zero = dataset_imputed_area["ISI"] != 0
new_data = dataset_imputed_area[non_zero]

univariate_analysys("Log transformed ISI", np.sqrt(new_data['ISI']))
# Out:
# Mean: 2.916937063797845
# Median: 2.898275349237888
# Mode: 3.0983866769659336
# Range: 6.857537792395926
# Variance: 0.5316557933488955
# Standard Deviation: 0.729147305658394
# Measure of Skewness: 0.25560107840645424

# %% [markdown]
# temp

# %%
univariate_analysys("Temperature", dataset_imputed_area["temp"])
# Out:
# Mean: 18.88916827852998
# Median: 19.3
# Mode: 17.4
# Range: 31.099999999999998
# Variance: 33.7168979503096
# Standard Deviation: 5.806625349573503
# Measure of Skewness: -0.331172237347285

# %% [markdown]
# RH

# %%
univariate_analysys("RH", dataset_imputed_area["RH"])
# Out:
# Mean: 44.28820116054158
# Median: 42.0
# Mode: 27
# Range: 85
# Variance: 266.2598023780601
# Standard Deviation: 16.317469239378394
# Measure of Skewness: 0.8629040078552522

# %% [markdown]
# wind

# %%
univariate_analysys("Wind", dataset_imputed_area["wind"])
# Out:
# Mean: 4.017601547388782
# Median: 4.0
# Mode: 2.2
# Range: 9.0
# Variance: 3.2100190424782165
# Standard Deviation: 1.7916526009464604
# Measure of Skewness: 0.5710011270000588

# %% [markdown]
# rain

# %%
univariate_analysys("Rain", dataset_imputed_area["rain"])
# Out:
# Mean: 0.021663442940038684
# Median: 0.0
# Mode: 0.0
# Range: 6.4
# Variance: 0.08759180123851085
# Standard Deviation: 0.29595912089089405
# Measure of Skewness: 19.816343982813166

# %% [markdown]
# Data is right skewed

# %%
univariate_analysys("Temperature", np.sqrt(dataset_imputed_area["temp"]))
# Out:
# Mean: 4.28474129298793
# Median: 4.39317652729776
# Mode: 4.171330722922842
# Range: 4.287375521082271
# Variance: 0.5311877731954494
# Standard Deviation: 0.7288262983698169
# Measure of Skewness: -0.9349343169331903

# %% [markdown]
# area

# %%
univariate_analysys("Area", dataset_imputed_area['area'])
# Out:
# Mean: 15.890599613152805
# Median: 6.37
# Mode: 6.37
# Range: 1090.75
# Variance: 3983.8589281281343
# Standard Deviation: 63.11781783401684
# Measure of Skewness: 13.036463521081872

# %%
univariate_analysys("Area", np.log(dataset_imputed_area['area']))
# Out:
# Mean: 1.8480647243101112
# Median: 1.851599469584072
# Mode: 1.851599469584072
# Range: 9.402648929284666
# Variance: 1.2151254155734361
# Standard Deviation: 1.102327272443822
# Measure of Skewness: 0.40492334205265545

# %% [markdown]
# ##### 4B - Bivariate Analysis

# %% [markdown]
# Lets setup data for bivariant analysis from previous analysis

# %%
data_bivariant = dataset_imputed_area.copy()
lambda_value = 16
data_bivariant['FFMC'] = boxcox(data_bivariant['FFMC'], lmbda=lambda_value)
lambda_value = 4
data_bivariant['DC'] = boxcox(data_bivariant['DC'], lmbda=lambda_value)
data_bivariant.drop(data_bivariant[data_bivariant['DC'] == 0].index, inplace=True)
data_bivariant['ISI'] = np.sqrt(data_bivariant['ISI'])
data_bivariant["temp"] = np.sqrt(data_bivariant["temp"])
data_bivariant['area'] = np.log(dataset_imputed_area['area'])

# %%
# Create a list of variables
variables = ['FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH', 'wind', 'rain', 'area']

# Create a pairplot
sns.pairplot(data_bivariant[variables])
plt.suptitle('Pairplot of Variables')
plt.show()

# %%
# Create a heatmap
variables = ['FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH', 'wind', 'rain', 'area']
data_heat = data_bivariant[variables]

sns.heatmap(data_heat.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ##### 4C - Multivariate Analysis

# %% [markdown]
# ##### 4D - Feature Engineering

# %% [markdown]
# ##### 4E - Removing Outliers

# %% [markdown]
# ##### 4F - Imputing missing values

# %% [markdown]
# ##### 4G - Repeat EDA until done

# %% [markdown]
# ### Step 5 - Documenting conclusions

# %% [markdown]
# ### Step 6 - Modeling

# %% [markdown]
# ### Step 7 - Hyperparameter tuning

# %% [markdown]
# ### Step 8 - Visualizing results

# %% [markdown]
# ### Step 9 - Deployment
